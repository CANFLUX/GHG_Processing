# %%
import os
# import struct
import numpy as np
import pandas as pd
# print(os.cwd)

os.getcwd()

Dir = 'W:\\2022\\BB\\Flux\\'

Trace = 'co2_mean'
Time = 'clean_tv'

data_file = Dir + Trace
time_file = Dir + Time

# with open(filename, mode='rb') as file:
    # if Trace == 'clean_tv':
Time = np.fromfile(open(time_file, mode='rb'), 'float32')
    # else:
Var = np.fromfile(open(data_file, mode='rb'), 'float32')
# # print(Var.shape,Time.shape)

# df = pd.DataFrame(data = {
#     'Timestamp':Time,
#     'Var':Var
# })

print(Var.shape)
print(2*24*365)

# print(Time.shape)
# Time = Time.reshape(-1,2)
# Time
# pd.to_datetime(Time,unit='s')

    
#     Data = np.array(struct.unpack("i" * ((len(fileContent) -24) // 4), fileContent[20:-4]))
# Out:
# (17520,)
# 17520

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(Time)
# plt.ylim(0,1000)

# %%
# PSTS = pd.read_csv('Z:\BBS\CR10X_PSTS_final_storage_1.dat')

# # PSTS[[-6999	-6999.1	-6999.2]]
# PSTS.columns=['Array','Year','DOY','Time','PTemp','5_S','10_S','30_S','5_R','10_R','30_R']

# PSTS = PSTS.loc[PSTS['Array']==111]
# PSTS[PSTS<-10] = np.nan
# PSTS.loc[PSTS['DOY']<=66] = np.nan
# PSTS.loc[PSTS['DOY']>=77] = np.nan
# print(PSTS.loc[((PSTS['Time']<1400)&(PSTS['Time']>1000)),
# ['5_S','10_S','30_S','5_R','10_R','30_R']].mean())

# print(PSTS.loc[((PSTS['Time']<600)),
# ['5_S','10_S','30_S','5_R','10_R','30_R']].mean())


# fig,ax = plt.subplots(2)
# # plt.plot(PL)

# PSTS.groupby('Time').mean()[['5_S','10_S','30_S']].plot(ax=ax[0])
# PSTS.groupby('Time').mean()[['5_R','10_R','30_R']].plot(ax=ax[1])


# # PSTS[['5_S','10_S','30_S','5_R','10_R','30_R']].plot()
# PSTS.describe()
# Out:
# 5_S     2.255578
# 10_S    1.925370
# 30_S    2.494378
# 5_R     1.676322
# 10_R    1.363709
# 30_R    2.004009
# dtype: float64
# 5_S     4.406163
# 10_S    5.204551
# 30_S    5.273757
# 5_R     4.999400
# 10_R    4.808969
# 30_R    5.034346
# dtype: float64
#         Array    Year         DOY         Time        PTemp          5_S  \
# count  2880.0  2880.0  2880.00000  2880.000000  2880.000000  2880.000000
# mean    111.0  2023.0    71.50000  1191.666667     4.635275     4.525302
# std       0.0     0.0     2.87278   692.950661     5.476558     1.843700
# min     111.0  2023.0    67.00000    10.000000    -5.305000    -1.540000
# 25%     111.0  2023.0    69.00000   607.500000     0.401750     3.697750
# 50%     111.0  2023.0    71.50000  1205.000000     4.189500     4.654500
# 75%     111.0  2023.0    74.00000  1802.500000     8.230000     5.731750
# max     111.0  2023.0    76.00000  2400.000000    16.890000     8.430000
#
# ...

# %%
# PSLS = pd.read_csv('Z:\BBS\CR10X_PSLS_final_storage_1.dat')

# # PSLS[[-6999	-6999.1	-6999.2]]
# PSLS.columns=['Array','Year','DOY','Time','PTemp','5_S','10_S','30_S','5_R','10_R','30_R']


# PSLS = PSLS.loc[PSLS['Array']==101]
# PSLS[PSLS<-10] = np.nan
# PSLS.loc[PSLS['DOY']<=66] = np.nan
# PSLS.loc[PSLS['DOY']>=77] = np.nan



# # PSLS['JS'] = pd.to_datetime(PSLS['Year'] * 1000 + PSLS['DOY'], format='%Y%j')



# print(PSLS.loc[((PSLS['Time']<1400)&(PSLS['Time']>1000)),
# ['5_S','10_S','30_S','5_R','10_R','30_R']].mean())

# print(PSLS.loc[((PSLS['Time']<600)),
# ['5_S','10_S','30_S','5_R','10_R','30_R']].mean())

# fig,ax=plt.subplots(2)
# # plt.plot(PL)

# # PSLS.groupby('Time').mean()[['5_S','10_S','30_S','5_R','10_R','30_R']].plot()


# PSLS.groupby('Time').mean()[['5_S','10_S','30_S']].plot(ax=ax[0])
# PSLS.groupby('Time').mean()[['5_R','10_R','30_R']].plot(ax=ax[1])


# PSLS.describe()
